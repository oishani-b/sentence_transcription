# %%
import os
import pandas as pd
import numpy as np

# %%
def get_participant_model_column(full_folder_path, participant_id, model):

    fname_list = []
    transcript_list = []
    participant_id_list = []
    sentence_ids_list = []
    iterations_list = []
    
    for file in os.listdir(full_folder_path):
        if 'whisper' not in file and file.endswith('.txt') and model in file:
            
            fname_list.append(file)
            
            full_fname = os.path.join(full_folder_path, file)
            ids = file.split('_')[6:9]
            sentence_id = ids[0] + '_' + ids[1]
            sentence_ids_list.append(sentence_id)

            iteration = ids[2]
            iterations_list.append(iteration)
            
            with open(full_fname, 'r') as f:
                transcript = f.read()
                transcript = transcript.strip()
                #print(transcript)
                transcript_list.append(transcript)

            participant_id_list.append(participant_id)

    result_df = pd.DataFrame({'participant_id':participant_id_list})

    result_df['file_name'] = fname_list # kept for debugging

    result_df['Sentence ID'] = sentence_ids_list

    result_df['Iteration'] = iterations_list

    result_df[model] = transcript_list

    return result_df

# %%
def merging_models_per_participant(full_folder_path, participant_id):
    df_merged = get_participant_model_column(
    full_folder_path, participant_id, 'large')
    
    model_list = ['base', 'medium', 'small', 'tiny']
    for model in model_list:
        model_df = get_participant_model_column(
            full_folder_path, participant_id, model)
        
        df_merged = df_merged.merge(
            model_df[['participant_id', 'Sentence ID', 'Iteration', model]],
            on = ['participant_id', 'Sentence ID', 'Iteration'],
            how = 'inner')

    return df_merged

# %%
def merge_with_targets(participant_df):
    target_sentence_df = pd.read_csv('target_sentences.csv')
    
    merged_df = participant_df.merge(
        target_sentence_df, on = 'Sentence ID', how = 'left')

    merged_df = merged_df[['participant_id', 'Sentence ID', 
                           'Iteration', 'probability', 'Expected Transcription',
                           'large', 'base', 'medium', 
                           'small', 'tiny']].reindex()
    return merged_df

# %%
def full_txt_to_df(full_sauce_folder_path, participant_id, destination_path):
    participant_df = merging_models_per_participant(
        full_sauce_folder_path, participant_id)

    full_df = merge_with_targets(participant_df)
    
    full_df.to_csv(destination_path)

    return full_df

# %%
full_txt_to_df('/Users/cogsci-lasrlab1/Desktop/MTAA_recording/t13/t13_sauce', 
               't13', 
               '/Users/cogsci-lasrlab1/Desktop/MTAA_recording/t13/t13_sauce/t13_sauce.csv')
# Out:
#     participant_id Sentence ID Iteration probability  \
# 0              t13        38_3      R5P1    low prob
# 1              t13        14_3        L2     nonword
# 2              t13        48_2        L1    low prob
# 3              t13        72_1        L1     nonword
# 4              t13        63_3        L1     nonword
# ..             ...         ...       ...         ...
# 679            t13        29_3        L2     nonword
# 680            t13        75_2        L1   high prob
# 681            t13        38_1        L2     nonword
# 682            t13        16_2      R2P1   high prob
# 683            t13        10_3        L1   high prob
#
#                                 Expected Transcription  \
# 0          I fixed the torn page with a piece of book.
# 1          To play mug of war, we pulled on the grass.
# 2      We moved our furniture on the back of a flower.
# 3                    The coy has a toy choo-choo leaf.
# 4    I fell in the hud and have to put on a new but...
# ..                                                 ...
# 679                     The tift was inside the zebra.
# 680           To drive the car, daddy turns the wheel.
# 681        I fixed the torn mage with a piece of book.
# 682       On the ceiling I saw a creepy-crawly spider.
# 683             Watch the astronaut launch the rocket.
#
#                                                  large  \
# 0          I fixed the torn page with a piece of book.
# 1          To play mug of war, we pulled on the grass.
# 2    We've moved our furniture on the back of a flo...
# 3                    The koi has a toy choo-choo leaf.
# 4    I fell in the hut and have to put on a new but...
# ..                                                 ...
# 679                     The tift was inside the zebra.
# 680          To drive the cart, daddy turns the wheel.
# 681          I fix the torn page with a piece of book.
# 682    On the ceiling, I saw a creepy crawling spider.
# 683              Watch the astronaut lands the rocket.
#
#                                                   base  \
# 0          I fixed the torn page with a piece of book.
# 1           To play Mug of War we pulled on the grass.
# 2    We've moved our furniture on the back of the f...
# 3                    The coin has a toy choo cho leaf.
# 4    I fell in the HUD and have to put on a new but...
# ..                                                 ...
# 679                     The tent was inside the zebra.
# 680           To drive the car, Daddy turns the wheel.
# 681     I fixed the Torpate Mage with a piece of book.
# 682      On the selling I saw a creepy curling spider.
# 683               Watch the astronaut lands to rocket.
#
#                                                 medium  \
# 0          I fixed the torn page with a piece of book.
# 1          To play Mug of War, we pulled on the grass.
# 2    We've moved our furniture on the back of a flo...
# 3                    The koi has a toy choo choo leaf.
# 4    I fell in the HUD and have to put on a new but...
# ..                                                 ...
# 679                   The tipped was inside the zebra.
# 680           To drive the car, daddy turns the wheel.
# 681       I fixed the Torp Mages with a piece of book.
# 682     On the selling I saw a creepy crawling spider.
# 683               Watch the astronaut land the rocket.
#
#                                                  small  \
# 0          I fixed the torn page with a piece of book.
# 1           To play mug of war we pulled on the grass.
# 2    We've moved our furniture on the back of a flo...
# 3                       The koi has a toy chuchu leaf.
# 4    I fell in the HUD and have to put on a new but...
# ..                                                 ...
# 679                     The tiff was inside the zebra.
# 680           To drive the car, Daddy turns the wheel.
# 681        I fixed the tour page with a piece of book.
# 682      On the ceiling I saw a creepy curling spider.
# 683             Watch the astronaut launch the rocket.
#
#                                                   tiny
# 0          I fixed the torn page with a piece of book.
# 1           To play Mug of War we pulled on the grass.
# 2    We've moved our furniture on the back of a flo...
# 3                           The Coi has a toy to live.
# 4    I fell in the hood and have to put on a new bu...
# ..                                                 ...
# 679                      The TFT was inside the zebra.
# 680         To drive the car, that he turns the wheel.
# 681      I fixed the tour page with the piece of book.
# 682     On the selling I saw a creepy crawling spider.
# 683              Watch the astronaut lands to rock it.
#
# [684 rows x 10 columns]
