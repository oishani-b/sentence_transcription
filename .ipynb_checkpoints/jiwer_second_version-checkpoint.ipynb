# %% [markdown]
# ## Imports for Jiwer

# %%
import jiwer
from jiwer import wer
import pandas as pd
import os

# %% [markdown]
# ## Testing with Participants Individually

# %%
test_t57_df = pd.read_csv('/Users/oishanibandopadhyay/Documents/LASR_Whisper_SAUCE/MTAA_recording/t57/t57_sauce/t57_sauce.csv')
test_t57_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 test_t57_df = pd.read_csv('/Users/oishanibandopadhyay/Documents/LASR_Whisper_SAUCE/MTAA_recording/t57/t57_sauce/t57_sauce.csv')
#       2 test_t57_df
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/oishanibandopadhyay/Documents/LASR_Whisper_SAUCE/MTAA_recording/t57/t57_sauce/t57_sauce.csv'

# %%
test_t33_df = pd.read_csv('/Users/oishanibandopadhyay/Documents/LASR_Whisper_SAUCE/MTAA_recording/t33/t33_sauce/t33_sauce.csv')
test_t33_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 test_t33_df = pd.read_csv('/Users/oishanibandopadhyay/Documents/LASR_Whisper_SAUCE/MTAA_recording/t33/t33_sauce/t33_sauce.csv')
#       2 test_t33_df
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/oishanibandopadhyay/Documents/LASR_Whisper_SAUCE/MTAA_recording/t33/t33_sauce/t33_sauce.csv'

# %%
# standardize string inputs to make more accurate wer counts
def pre_jiwer_standardize(any_string):
    wer_standardize = jiwer.Compose(
    [
        jiwer.ToLowerCase(),
        # jiwer.ExpandCommonEnglishContractions(),
        # jiwer.RemoveKaldiNonWords(),
        jiwer.RemoveWhiteSpace(replace_by_space=True),
        jiwer.RemoveMultipleSpaces(),
        jiwer.Strip(),
        jiwer.RemovePunctuation()
    ]
    )
    any_string = str(any_string).replace("neighbourhood", "neighborhood")

    return wer_standardize(any_string)

# %%
sent_88_1 = pre_jiwer_standardize("Daddy's shirt was missing a button.")
sent_88_1
sent_88_1 = jiwer.ReduceToListOfListOfWords()(sent_88_1)
sent_88_1
# Out:
# [['daddys', 'shirt', 'was', 'missing', 'a', 'button']]

# %%
sent_6_1 = pre_jiwer_standardize("The scared turtle won't come out of its shell.")
sent_6_1
#sent_6_1 = jiwer.ReduceToListOfListOfWords()(sent_6_1)
sent_6_1
# Out:
# 'the scared turtle wont come out of its shell'

# %%
eg_whisp_6_1 = pre_jiwer_standardize("The scared turtle won't come out of its shell.")
#eg_whisp_6_1 = jiwer.ReduceToListOfListOfWords()(eg_whisp_6_1)
eg_whisp_6_1
# Out:
# 'the scared turtle wont come out of its shell'

# %%
wer(sent_6_1, eg_whisp_6_1)
# Out:
# 0.0

# %%
# what makes sense to fix?
# we can use jiwer, see if the output is non-zero, then add our corrections
# our corrections can involve dictionary substitutions for allowances
# we should also come up with a way to generaize for non-words here

# maybe we start with large, because that's likely to catch all the subs possible

# %%
# applying transformation for preprocessing prompt/transcript columns
def transform_col_text(df, col_name, new_col_name):
    df_copy = df.copy()
    df_copy.loc[:,new_col_name] = df_copy[col_name].apply(pre_jiwer_standardize)
    return df_copy


# creating a new wer getting row-wise error rates for transformed strings in col1, col2
def wer_transformed(df, wer_col, col1, col2):
    df_copy = df.copy()
    df_copy.loc[:, wer_col] = df.apply(lambda x:
                                  wer(x[col1], x[col2]), axis=1)
    return df_copy

# %%
# test
# df_orig = pd.read_csv('partic_transcripts.csv')
test_t33_df
df_expected_preprocessed = transform_col_text(test_t33_df,
                                              'Expected Transcription',
                                              'preproc_exp_transc')
df_large_preprocessed = transform_col_text(df_expected_preprocessed,
                                           'large',
                                           'large_preproc')
df_base_preprocessed = transform_col_text(df_large_preprocessed,
                                           'base',
                                           'base_preproc')
df_medium_preprocessed = transform_col_text(df_base_preprocessed,
                                           'medium',
                                           'medium_preproc')
df_small_preprocessed = transform_col_text(df_medium_preprocessed,
                                           'small',
                                           'small_preproc')
df_tiny_preprocessed = transform_col_text(df_small_preprocessed,
                                           'tiny',
                                           'tiny_preproc')

df_preproc_final = df_tiny_preprocessed
df_preproc_final.head()
df_preproc_final.to_csv('t33_preproc_test.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 # test
#       2 # df_orig = pd.read_csv('partic_transcripts.csv')
# ----> 3 test_t33_df
#       4 df_expected_preprocessed = transform_col_text(test_t33_df,
#       5                                               'Expected Transcription',
#       6                                               'preproc_exp_transc')
#       7 df_large_preprocessed = transform_col_text(df_expected_preprocessed,
#       8                                            'large',
#       9                                            'large_preproc')
#
# NameError: name 'test_t33_df' is not defined

# %%
# Adding WER
df_wer = wer_transformed(df_preproc_final, 
                         'large_wer', 
                         'preproc_exp_transc', 
                         'large_preproc')
df_wer = wer_transformed(df_wer, 
                         'base_wer', 
                         'preproc_exp_transc', 
                         'base_preproc')

df_wer = wer_transformed(df_wer, 
                         'medium_wer', 
                         'preproc_exp_transc', 
                         'medium_preproc')

df_wer = wer_transformed(df_wer, 
                         'small_wer', 
                         'preproc_exp_transc', 
                         'small_preproc')

df_wer = wer_transformed(df_wer, 
                         'tiny_wer', 
                         'preproc_exp_transc', 
                         'tiny_preproc')
df_wer.head()
df_wer.to_csv('t33_wer_test.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Adding WER
# ----> 2 df_wer = wer_transformed(df_preproc_final,
#       3                          'large_wer',
#       4                          'preproc_exp_transc',
#       5                          'large_preproc')
#       6 df_wer = wer_transformed(df_wer,
#       7                          'base_wer',
#       8                          'preproc_exp_transc',
#       9                          'base_preproc')
#      11 df_wer = wer_transformed(df_wer,
#      12                          'medium_wer',
#      13                          'preproc_exp_transc',
#      14                          'medium_preproc')
#
# NameError: name 'df_preproc_final' is not defined

# %%
# ok we're working with df_wer

# %%
df_wer.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df_wer.head()
#
# NameError: name 'df_wer' is not defined

# %% [markdown]
# ### Inspecting df_wer by low probability and large transcriptions

# %%
# keeping only the relevant columns, and only low prob sentences

# %%
df_relevant = df_wer[['participant_id', 'Sentence ID', 'Iteration', 'probability', 'preproc_exp_transc', 'large_preproc', 'large_wer']]
df_relevant = df_relevant.loc[df_relevant['probability'] == 'low prob']
df_relevant.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df_relevant = df_wer[['participant_id', 'Sentence ID', 'Iteration', 'probability', 'preproc_exp_transc', 'large_preproc', 'large_wer']]
#       2 df_relevant = df_relevant.loc[df_relevant['probability'] == 'low prob']
#       3 df_relevant.head()
#
# NameError: name 'df_wer' is not defined

# %%
df_relevant.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df_relevant.shape
#
# NameError: name 'df_relevant' is not defined

# %%
# look at only the wer > 0 rows
df_relevant = df_relevant.loc[df_relevant['large_wer'] > 0]
df_relevant
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 # look at only the wer > 0 rows
# ----> 2 df_relevant = df_relevant.loc[df_relevant['large_wer'] > 0]
#       3 df_relevant
#
# NameError: name 'df_relevant' is not defined

# %% [markdown]
# ###

# %% [markdown]
# ## Testing with Main Dataframe

# %%
# loading original dataframe with transcript columns
df_orig = pd.read_csv('partic_transcripts.csv')

# %%
# applying column-wise jiwer preprocessing on all text columns
df_expected_preprocessed = transform_col_text(df_orig,
                                              'Expected Transcription',
                                              'preproc_exp_transc')
df_large_preprocessed = transform_col_text(df_expected_preprocessed,
                                           'large',
                                           'large_preproc')
df_base_preprocessed = transform_col_text(df_large_preprocessed,
                                           'base',
                                           'base_preproc')
df_medium_preprocessed = transform_col_text(df_base_preprocessed,
                                           'medium',
                                           'medium_preproc')
df_small_preprocessed = transform_col_text(df_medium_preprocessed,
                                           'small',
                                           'small_preproc')
df_tiny_preprocessed = transform_col_text(df_small_preprocessed,
                                           'tiny',
                                           'tiny_preproc')

df_preproc_final = df_tiny_preprocessed
df_preproc_final.head()
df_preproc_final.to_csv('second_jiwer_preprocessed_oishani.csv')

# %%
# Adding WER
df_wer = wer_transformed(df_preproc_final, 
                         'large_wer', 
                         'preproc_exp_transc', 
                         'large_preproc')
df_wer = wer_transformed(df_wer, 
                         'base_wer', 
                         'preproc_exp_transc', 
                         'base_preproc')

df_wer = wer_transformed(df_wer, 
                         'medium_wer', 
                         'preproc_exp_transc', 
                         'medium_preproc')

df_wer = wer_transformed(df_wer, 
                         'small_wer', 
                         'preproc_exp_transc', 
                         'small_preproc')

df_wer = wer_transformed(df_wer, 
                         'tiny_wer', 
                         'preproc_exp_transc', 
                         'tiny_preproc')
df_wer.head()
df_wer.to_csv('second_wer_oishani.csv')

# %%
df_relevant = df_wer.loc[(df_wer['large_wer'] > 0) & (df_wer['probability'] == "low prob")]
df_relevant
# Out:
#        Unnamed: 0 participant_id  \
# 0               0            t45
# 4               4            t45
# 22             22            t45
# 27             27            t45
# 78             78            t45
# ...           ...            ...
# 51164       51164             t7
# 51170       51170             t7
# 51178       51178             t7
# 51190       51190             t7
# 51192       51192             t7
#
#                                               file_name Sentence ID Iteration  \
# 0      t45_M_EN_SAUCE_block0_sauce_25_3_L2_large-v3.txt        25_3        L2
# 4      t45_M_EN_SAUCE_block0_sauce_37_2_L1_large-v3.txt        37_2        L1
# 22     t45_M_EN_SAUCE_block0_sauce_11_3_L2_large-v3.txt        11_3        L2
# 27     t45_M_EN_SAUCE_block0_sauce_66_3_L1_large-v3.txt        66_3        L1
# 78     t45_M_EN_SAUCE_block0_sauce_36_2_L1_large-v3.txt        36_2        L1
# ...                                                 ...         ...       ...
# 51164   t7_F_MN_SAUCE_block0_sauce_77_3_L2_large-v3.txt        77_3        L2
# 51170   t7_F_MN_SAUCE_block0_sauce_66_3_L1_large-v3.txt        66_3        L1
# 51178    t7_F_MN_SAUCE_block0_sauce_5_2_L2_large-v3.txt         5_2        L2
# 51190   t7_F_MN_SAUCE_block0_sauce_37_2_L1_large-v3.txt        37_2        L1
# 51192   t7_F_MN_SAUCE_block0_sauce_25_3_L2_large-v3.txt        25_3        L2
#
#       probability                             Expected Transcription  \
# 0        low prob          When I get a cold I have a runny pumpkin.
# 4        low prob                Grandma sits on her porch in a bat.
# 22       low prob                         The spider spun a big car.
# 27       low prob  For breakfast, Mommy poured me a bowl of butte...
# 78       low prob               Sitting on the lilypad was a bridge.
# ...           ...                                                ...
# 51164    low prob            The aquarium has many different swings.
# 51170    low prob  For breakfast, Mommy poured me a bowl of butte...
# 51178    low prob                           She got stung by a flag.
# 51190    low prob                Grandma sits on her porch in a bat.
# 51192    low prob          When I get a cold I have a runny pumpkin.
#
#                                                    large  \
# 0              When I get cold I have a running pumpkin.
# 4                    Grandma sits on her porch in a bed.
# 22                         The spider spawned a big car.
# 27     For breakfast, mommy pour me a bowl of butterfly.
# 78                 Sitting on the lady pad was a bridge.
# ...                                                  ...
# 51164               The Korean has many different twins.
# 51170  For breakfast, Mommy pulled me a bowl of butte...
# 51178                         She got stunned by a flag.
# 51190             Grandma sits on her porch in the bath.
# 51192     When I got a coat, I have a round and pumpkin.
#
#                                                     base  \
# 0              When I get cold I have a running pumpkin.
# 4                    Grandma sits on her porch in a bed.
# 22                          This spider spawn a big car.
# 27     For breakfast, Mommy poured me a bowl of butte...
# 78               Sitting on the lady power was a bridge.
# ...                                                  ...
# 51164            The aquarium has many different swings.
# 51170  For breakfast mommy pulled me a bowl of butter...
# 51178                         She goes down by her flag.
# 51190         Garant must sits on her porch in the back.
# 51192       When I got a code, I have a running pub kit.
#
#                                                   medium  ...  \
# 0                When I get cold I have a runny pumpkin.  ...
# 4                  Grandma sits on her porch in the bed.  ...
# 22                          The spiders spawn a big car.  ...
# 27      For breakfast, mommy pour me a bow of butterfly.  ...
# 78                 Sitting on the lady pad was a bridge.  ...
# ...                                                  ...  ...
# 51164              The Korean has many different swings.  ...
# 51170  For breakfast, mommy pulled me a bowl of butte...  ...
# 51178                         She got stunned by a flag.  ...
# 51190             Grandma sits on her porch in the bath.  ...
# 51192       When I got a coat, I have a running pumpkin.  ...
#
#                                            large_preproc  \
# 0               when i get cold i have a running pumpkin
# 4                     grandma sits on her porch in a bed
# 22                          the spider spawned a big car
# 27       for breakfast mommy pour me a bowl of butterfly
# 78                  sitting on the lady pad was a bridge
# ...                                                  ...
# 51164                the korean has many different twins
# 51170  for breakfast mommy pulled me a bowl of butterfly
# 51178                          she got stunned by a flag
# 51190              grandma sits on her porch in the bath
# 51192       when i got a coat i have a round and pumpkin
#
#                                             base_preproc  \
# 0               when i get cold i have a running pumpkin
# 4                     grandma sits on her porch in a bed
# 22                           this spider spawn a big car
# 27     for breakfast mommy poured me a bowl of butterfly
# 78                sitting on the lady power was a bridge
# ...                                                  ...
# 51164             the aquarium has many different swings
# 51170  for breakfast mommy pulled me a bowl of butterfly
# 51178                          she goes down by her flag
# 51190          garant must sits on her porch in the back
# 51192         when i got a code i have a running pub kit
#
#                                           medium_preproc  \
# 0                 when i get cold i have a runny pumpkin
# 4                   grandma sits on her porch in the bed
# 22                           the spiders spawn a big car
# 27        for breakfast mommy pour me a bow of butterfly
# 78                  sitting on the lady pad was a bridge
# ...                                                  ...
# 51164               the korean has many different swings
# 51170  for breakfast mommy pulled me a bowl of butterfly
# 51178                          she got stunned by a flag
# 51190              grandma sits on her porch in the bath
# 51192         when i got a coat i have a running pumpkin
#
#                                            small_preproc  \
# 0               when i get cold i have a running pumpkin
# 4                   grandma sits on her porch in the bed
# 22                           the spiders spawn a big car
# 27     for breakfast mommy poured me a bowl of butterfly
# 78                sitting on the lili power was a bridge
# ...                                                  ...
# 51164                the korean has many different twins
# 51170  for breakfast mommy pulled me a bowl of butterfly
# 51178                              shikha stan by a flag
# 51190             garretma sits on her porch in the bath
# 51192         when i got a coat i have a running pumpkin
#
#                                             tiny_preproc large_wer  base_wer  \
# 0               when i get cold i have a running pumpkin  0.200000  0.200000
# 4                     grandma sits on her porch in a bed  0.125000  0.125000
# 22                            the spider spawn a big car  0.166667  0.333333
# 27     for breakfast mommy poured me a bowl of butterfly  0.111111  0.000000
# 78                 sitting on the lay power was a bridge  0.285714  0.285714
# ...                                                  ...       ...       ...
# 51164                the korean has many different swins  0.333333  0.000000
# 51170  for breakfast mommy pulled me a bowl of butterfly  0.111111  0.111111
# 51178                                shikostan by a flag  0.166667  0.500000
# 51190            grant must sits on her porch in the bed  0.250000  0.500000
# 51192         when i got a code i have a running pumpkin  0.400000  0.500000
#
#       medium_wer  small_wer  tiny_wer
# 0       0.100000   0.200000  0.200000
# 4       0.250000   0.250000  0.125000
# 22      0.333333   0.333333  0.166667
# 27      0.222222   0.000000  0.000000
# 78      0.285714   0.285714  0.285714
# ...          ...        ...       ...
# 51164   0.166667   0.333333  0.333333
# 51170   0.111111   0.111111  0.111111
# 51178   0.166667   0.500000  0.500000
# 51190   0.250000   0.375000  0.500000
# 51192   0.300000   0.300000  0.300000
#
# [6574 rows x 23 columns]
