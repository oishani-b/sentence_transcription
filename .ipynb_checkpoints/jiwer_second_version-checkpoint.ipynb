# %% [markdown]
# ## Imports for Jiwer

# %%
import jiwer
from jiwer import wer
import pandas as pd
import os

# %% [markdown]
# ## Testing with Participants Individually

# %%
test_t57_df = pd.read_csv('/Users/oishanibandopadhyay/Documents/LASR_Whisper_SAUCE/MTAA_recording/t57/t57_sauce/t57_sauce.csv')
test_t57_df
# Out:
#      Unnamed: 0 participant_id Sentence ID Iteration probability  \
# 0             0            t57        88_2        L2    low prob
# 1             1            t57        99_1      R4P1   high prob
# 2             2            t57        61_2        L1    low prob
# 3             3            t57        73_3        L2     nonword
# 4             4            t57        62_1        L2    low prob
# ..          ...            ...         ...       ...         ...
# 661         661            t57        28_1        L1     nonword
# 662         662            t57        65_2        L2     nonword
# 663         663            t57        39_3        L1   high prob
# 664         664            t57        66_1        L1   high prob
# 665         665            t57        77_3        L1    low prob
#
#                                 Expected Transcription  \
# 0                    Daddy's shirt was missing a fork.
# 1           To cross the river, we walked on a bridge.
# 2               I used 3 big snowballs to make a bear.
# 3    Use the resote to change the channels on the c...
# 4           The cowboy is very good at riding his hat.
# ..                                                 ...
# 661  First put on your nocks, then put on your cray...
# 662        The coloring hook comes with a box of hair.
# 663                        The bunny nibbled a carrot.
# 664   For breakfast, Mommy poured me a bowl of cereal.
# 665            The aquarium has many different swings.
#
#                                                  large  \
# 0                    Daddy's shirt was missing a fork.
# 1           To cross the river, we walked on a bridge.
# 2           I used three big snowballs to make a bear.
# 3    Use the result to change the channels on the c...
# 4           The cowboy is very good at riding his hat.
# ..                                                 ...
# 661  First put on your nocks, then put on your cray...
# 662        The coloring hook comes with a box of hair.
# 663                        The bunny nibbled a carrot.
# 664   For breakfast, Mommy poured me a bowl of cereal.
# 665            The aquarium has many different swings.
#
#                                                   base  \
# 0                    Daddy's shirt was missing a fork.
# 1            To cross the river we walked on a bridge.
# 2            I use three big snowballs to make a bear.
# 3    Use the result to change the channels on the c...
# 4          The cowboy is very good at writing his hat.
# ..                                                 ...
# 661  First put on your knocks then put on your cray...
# 662           The color hook comes with a box of hair.
# 663                        The bunny nibbled a carrot.
# 664   For breakfast, mommy poured me a bowl of cereal.
# 665            The aquarium has many different swings.
#
#                                                 medium  \
# 0                    Daddy's shirt was missing a fork.
# 1           To cross the river, we walked on a bridge.
# 2           I used three big snowballs to make a bear.
# 3    Use the result to change the channels on the c...
# 4           The cowboy is very good at riding his hat.
# ..                                                 ...
# 661  First put on your nocks, then put on your cray...
# 662        The coloring hook comes with a box of hair.
# 663                        The bunny nibbled a carrot.
# 664   For breakfast, Mommy poured me a bowl of cereal.
# 665            The aquarium has many different swings.
#
#                                                  small  \
# 0                    Daddy's shirt was missing a fork.
# 1            To cross the river we walked on a bridge.
# 2            I use three big snowballs to make a bear.
# 3    Use the result to change the channels on the c...
# 4           The cowboy is very good at riding his hat.
# ..                                                 ...
# 661   First put on your nox, then put on your crayons.
# 662        The coloring hook comes with a box of hair.
# 663                        The bunny nibbled a carrot.
# 664   For breakfast, mommy poured me a bowl of cereal.
# 665            The aquarium has many different swings.
#
#                                                   tiny
# 0                    Daddy's shirt was missing a fork.
# 1            To cross the river we walked on a bridge.
# 2            I use three big snowballs to make a bear.
# 3    Use the result to change the channels on the c...
# 4          The cowboy is very good at writing his hat.
# ..                                                 ...
# 661  First put on your knocks, then put on your cro...
# 662        The coloring hook comes with a box of hair.
# 663                        The bunny nibbles a carrot.
# 664   For breakfast, mommy poured me a bowl of cereal.
# 665            The Aquarium has many different swings.
#
# [666 rows x 11 columns]

# %%
test_t33_df = pd.read_csv('/Users/oishanibandopadhyay/Documents/LASR_Whisper_SAUCE/MTAA_recording/t33/t33_sauce/t33_sauce.csv')
test_t33_df
# Out:
#      Unnamed: 0 participant_id Sentence ID Iteration probability  \
# 0             0            t33        67_1        L2     nonword
# 1             1            t33        76_3        L2   high prob
# 2             2            t33        29_1        L2    low prob
# 3             3            t33        64_2        L1    low prob
# 4             4            t33        38_3        L2    low prob
# ..          ...            ...         ...       ...         ...
# 709         709            t33         9_1        L1   high prob
# 710         710            t33        89_2        L1    low prob
# 711         711            t33        72_3        L1   high prob
# 712         712            t33        63_1        L1    low prob
# 713         713            t33        60_2        L2   high prob
#
#                                 Expected Transcription  \
# 0                The matterpillar turned into a piano.
# 1               The man checked the time on his watch.
# 2                       The gift was inside the zebra.
# 3        You can open the locked door with the shovel.
# 4          I fixed the torn page with a piece of book.
# ..                                                 ...
# 709                          I put shampoo in my hair.
# 710  When we lost electricity, we had to light a mo...
# 711                 The boy has a toy choo-choo train.
# 712  I fell in the mud and have to put on a new but...
# 713              The bank is where he keeps the money.
#
#                                                  large  \
# 0                 The caterpillar turned into a piano.
# 1               The man checked the time on his watch.
# 2                       The gift was inside the zebra.
# 3          You can open the lock door with the shovel.
# 4        I spicked the torn page with a piece of book.
# ..                                                 ...
# 709                          I put shampoo in my hair.
# 710  When you lost electricity, you had to light a ...
# 711                 The boy has a toy choo-choo train.
# 712  I fell in the mud and have to put out a new bu...
# 713                  The bank is where he keeps money.
#
#                                                   base  \
# 0                  The metapillar turned into a piano.
# 1               The men checked the time on his watch.
# 2                   The gate was inside the deep rock.
# 3          You can open the lock door with the shovel.
# 4     I spiked the tour and page with a piece of book.
# ..                                                 ...
# 709                        I push and pull in my hair.
# 710  When you lost electricity you had to light a m...
# 711                     The boy has the toy 2 2 train.
# 712  I fell in the mud and have to put out a new bu...
# 713                   The bank is where he gets money.
#
#                                                 medium  \
# 0                  The metapillar turned into a piano.
# 1                 The men check the time on his watch.
# 2                       The gift was inside the zebra.
# 3          You can open the lock door with the shovel.
# 4         I spiked the torn page with a piece of book.
# ..                                                 ...
# 709                          I put shampoo in my hair.
# 710  When you lost electricity, you had to light a ...
# 711               The boy has the toy choo choo train.
# 712  I fell in the mud and had to put out a new but...
# 713                   The bank is where he gets money.
#
#                                                  small  \
# 0                  The metapillar turned into a piano.
# 1               The men checked the time on his watch.
# 2                      The gift was inside the Deepra.
# 3        You can open the locked door with the shovel.
# 4         I spiked the torn page with a piece of book.
# ..                                                 ...
# 709                        I push and pull in my hair.
# 710  When you lost electricity, you had to light a ...
# 711               The boy has the toy choo choo train.
# 712  I fell in the mud and have to put out a new bu...
# 713                   The bank is where he gets money.
#
#                                                   tiny
# 0                         Metapolar turn into a piano.
# 1               The men checked the time on his watch.
# 2                        The kit was inside the zebra.
# 3           We can open a locked door with the shovel.
# 4          I speak the torn page with a piece of book.
# ..                                                 ...
# 709                     I push up and pull in my hair.
# 710    We lost electricity you had to light a monster.
# 711  wait a sec.\nthe boy has the toy hurt two two ...
# 712  I thought in the mud it had to put out a new b...
# 713                  The bank is where he keeps money.
#
# [714 rows x 11 columns]

# %%
# standardize string inputs to make more accurate wer counts
def pre_jiwer_standardize(any_string):
    wer_standardize = jiwer.Compose(
    [
        jiwer.ToLowerCase(),
        # jiwer.ExpandCommonEnglishContractions(),
        # jiwer.RemoveKaldiNonWords(),
        jiwer.RemoveWhiteSpace(replace_by_space=True),
        jiwer.RemoveMultipleSpaces(),
        jiwer.Strip(),
        jiwer.RemovePunctuation()
    ]
    )
    any_string = str(any_string).replace("neighbourhood", "neighborhood")

    return wer_standardize(any_string)

# %%
sent_88_1 = pre_jiwer_standardize("Daddy's shirt was missing a button.")
sent_88_1
sent_88_1 = jiwer.ReduceToListOfListOfWords()(sent_88_1)
sent_88_1
# Out:
# [['daddys', 'shirt', 'was', 'missing', 'a', 'button']]

# %%
sent_6_1 = pre_jiwer_standardize("The scared turtle won't come out of its shell.")
sent_6_1
#sent_6_1 = jiwer.ReduceToListOfListOfWords()(sent_6_1)
sent_6_1
# Out:
# 'the scared turtle wont come out of its shell'

# %%
eg_whisp_6_1 = pre_jiwer_standardize("The scared turtle won't come out of its shell.")
#eg_whisp_6_1 = jiwer.ReduceToListOfListOfWords()(eg_whisp_6_1)
eg_whisp_6_1
# Out:
# 'the scared turtle wont come out of its shell'

# %%
wer(sent_6_1, eg_whisp_6_1)
# Out:
# 0.0

# %%
# what makes sense to fix?
# we can use jiwer, see if the output is non-zero, then add our corrections
# our corrections can involve dictionary substitutions for allowances
# we should also come up with a way to generaize for non-words here

# maybe we start with large, because that's likely to catch all the subs possible

# %%
# applying transformation for preprocessing prompt/transcript columns
def transform_col_text(df, col_name, new_col_name):
    df_copy = df.copy()
    df_copy.loc[:,new_col_name] = df_copy[col_name].apply(pre_jiwer_standardize)
    return df_copy


# creating a new wer getting row-wise error rates for transformed strings in col1, col2
def wer_transformed(df, wer_col, col1, col2):
    df_copy = df.copy()
    df_copy.loc[:, wer_col] = df.apply(lambda x:
                                  wer(x[col1], x[col2]), axis=1)
    return df_copy

# %%
# test
# df_orig = pd.read_csv('partic_transcripts.csv')
test_t33_df
df_expected_preprocessed = transform_col_text(test_t33_df,
                                              'Expected Transcription',
                                              'preproc_exp_transc')
df_large_preprocessed = transform_col_text(df_expected_preprocessed,
                                           'large',
                                           'large_preproc')
df_base_preprocessed = transform_col_text(df_large_preprocessed,
                                           'base',
                                           'base_preproc')
df_medium_preprocessed = transform_col_text(df_base_preprocessed,
                                           'medium',
                                           'medium_preproc')
df_small_preprocessed = transform_col_text(df_medium_preprocessed,
                                           'small',
                                           'small_preproc')
df_tiny_preprocessed = transform_col_text(df_small_preprocessed,
                                           'tiny',
                                           'tiny_preproc')

df_preproc_final = df_tiny_preprocessed
df_preproc_final.head()
df_preproc_final.to_csv('t33_preproc_test.csv')

# %%
# Adding WER
df_wer = wer_transformed(df_preproc_final, 
                         'large_wer', 
                         'preproc_exp_transc', 
                         'large_preproc')
df_wer = wer_transformed(df_wer, 
                         'base_wer', 
                         'preproc_exp_transc', 
                         'base_preproc')

df_wer = wer_transformed(df_wer, 
                         'medium_wer', 
                         'preproc_exp_transc', 
                         'medium_preproc')

df_wer = wer_transformed(df_wer, 
                         'small_wer', 
                         'preproc_exp_transc', 
                         'small_preproc')

df_wer = wer_transformed(df_wer, 
                         'tiny_wer', 
                         'preproc_exp_transc', 
                         'tiny_preproc')
df_wer.head()
df_wer.to_csv('t33_wer_test.csv')

# %%
# ok we're working with df_wer

# %%
df_wer.head()
# Out:
#    Unnamed: 0 participant_id Sentence ID Iteration probability  \
# 0           0            t33        67_1        L2     nonword
# 1           1            t33        76_3        L2   high prob
# 2           2            t33        29_1        L2    low prob
# 3           3            t33        64_2        L1    low prob
# 4           4            t33        38_3        L2    low prob
#
#                           Expected Transcription  \
# 0          The matterpillar turned into a piano.
# 1         The man checked the time on his watch.
# 2                 The gift was inside the zebra.
# 3  You can open the locked door with the shovel.
# 4    I fixed the torn page with a piece of book.
#
#                                            large  \
# 0           The caterpillar turned into a piano.
# 1         The man checked the time on his watch.
# 2                 The gift was inside the zebra.
# 3    You can open the lock door with the shovel.
# 4  I spicked the torn page with a piece of book.
#
#                                                base  \
# 0               The metapillar turned into a piano.
# 1            The men checked the time on his watch.
# 2                The gate was inside the deep rock.
# 3       You can open the lock door with the shovel.
# 4  I spiked the tour and page with a piece of book.
#
#                                          medium  \
# 0           The metapillar turned into a piano.
# 1          The men check the time on his watch.
# 2                The gift was inside the zebra.
# 3   You can open the lock door with the shovel.
# 4  I spiked the torn page with a piece of book.
#
#                                            small  ...  \
# 0            The metapillar turned into a piano.  ...
# 1         The men checked the time on his watch.  ...
# 2                The gift was inside the Deepra.  ...
# 3  You can open the locked door with the shovel.  ...
# 4   I spiked the torn page with a piece of book.  ...
#
#                                   large_preproc  \
# 0           the caterpillar turned into a piano
# 1         the man checked the time on his watch
# 2                 the gift was inside the zebra
# 3    you can open the lock door with the shovel
# 4  i spicked the torn page with a piece of book
#
#                                       base_preproc  \
# 0               the metapillar turned into a piano
# 1            the men checked the time on his watch
# 2                the gate was inside the deep rock
# 3       you can open the lock door with the shovel
# 4  i spiked the tour and page with a piece of book
#
#                                 medium_preproc  \
# 0           the metapillar turned into a piano
# 1          the men check the time on his watch
# 2                the gift was inside the zebra
# 3   you can open the lock door with the shovel
# 4  i spiked the torn page with a piece of book
#
#                                   small_preproc  \
# 0            the metapillar turned into a piano
# 1         the men checked the time on his watch
# 2                the gift was inside the deepra
# 3  you can open the locked door with the shovel
# 4   i spiked the torn page with a piece of book
#
#                                  tiny_preproc large_wer  base_wer  medium_wer  \
# 0                 metapolar turn into a piano  0.166667  0.166667    0.166667
# 1       the men checked the time on his watch  0.000000  0.125000    0.250000
# 2                the kit was inside the zebra  0.000000  0.500000    0.000000
# 3   we can open a locked door with the shovel  0.111111  0.111111    0.111111
# 4  i speak the torn page with a piece of book  0.100000  0.300000    0.100000
#
#    small_wer  tiny_wer
# 0   0.166667  0.500000
# 1   0.125000  0.125000
# 2   0.166667  0.166667
# 3   0.000000  0.222222
# 4   0.100000  0.100000
#
# [5 rows x 22 columns]

# %%
# keeping only the relevant columns, and only low prob sentences

# %%
df_relevant = df_wer[['participant_id', 'Sentence ID', 'Iteration', 'probability', 'preproc_exp_transc', 'large_preproc', 'large_wer']]
df_relevant = df_relevant.loc[df_relevant['probability'] == 'low prob']
df_relevant.head()
# Out:
#   participant_id Sentence ID Iteration probability  \
# 2            t33        29_1        L2    low prob
# 3            t33        64_2        L1    low prob
# 4            t33        38_3        L2    low prob
# 5            t33        10_1        L1    low prob
# 8            t33        76_1        L1    low prob
#
#                              preproc_exp_transc  \
# 2                 the gift was inside the zebra
# 3  you can open the locked door with the shovel
# 4    i fixed the torn page with a piece of book
# 5          watch the astronaut launch the santa
# 8        the man checked the time on his stairs
#
#                                   large_preproc  large_wer
# 2                 the gift was inside the zebra   0.000000
# 3    you can open the lock door with the shovel   0.111111
# 4  i spicked the torn page with a piece of book   0.100000
# 5          wish the astronaut launch the center   0.333333
# 8        the man checked the time on his stairs   0.000000

# %%
df_relevant.shape
# Out:
# (238, 7)

# %%
# look at only the wer > 0 rows
df_relevant = df_relevant.loc[df_relevant['large_wer'] > 0]
df_relevant
# Out:
#     participant_id Sentence ID Iteration probability  \
# 3              t33        64_2        L1    low prob
# 4              t33        38_3        L2    low prob
# 5              t33        10_1        L1    low prob
# 20             t33        42_3        L2    low prob
# 28             t33        80_2        L1    low prob
# ..             ...         ...       ...         ...
# 697            t33         9_3        L2    low prob
# 701            t33        14_1        L2    low prob
# 702            t33        59_2        L1    low prob
# 710            t33        89_2        L1    low prob
# 712            t33        63_1        L1    low prob
#
#                                     preproc_exp_transc  \
# 3         you can open the locked door with the shovel
# 4           i fixed the torn page with a piece of book
# 5                 watch the astronaut launch the santa
# 20       to keep the sun out of my face i wear a train
# 28            we roasted marshmallows over the giraffe
# ..                                                 ...
# 697                            i put shampoo in my pig
# 701          to play tug of war we pulled on the grass
# 702     at the playground the girl went on the oranges
# 710  when we lost electricity we had to light a mon...
# 712  i fell in the mud and have to put on a new button
#
#                                          large_preproc  large_wer
# 3           you can open the lock door with the shovel   0.111111
# 4         i spicked the torn page with a piece of book   0.100000
# 5                 wish the astronaut launch the center   0.333333
# 20        to keep the sun out of my face i wear a tray   0.083333
# 28             the roasted marshmallows of the giraffe   0.333333
# ..                                                 ...        ...
# 697                           i put shampoo in my pick   0.166667
# 701          to play tipup oil we pull it on the grass   0.500000
# 702         at playground the girl went on the oranges   0.111111
# 710  when you lost electricity you had to light a m...   0.200000
# 712  i fell in the mud and have to put out a new bu...   0.076923
#
# [149 rows x 7 columns]

# %% [markdown]
# ## Testing with Main Dataframe

# %%
# loading original dataframe with transcript columns
df_orig = pd.read_csv('partic_transcripts.csv')

# %%
# applying column-wise jiwer preprocessing on all text columns
df_expected_preprocessed = transform_col_text(df_orig,
                                              'Expected Transcription',
                                              'preproc_exp_transc')
df_large_preprocessed = transform_col_text(df_expected_preprocessed,
                                           'large',
                                           'large_preproc')
df_base_preprocessed = transform_col_text(df_large_preprocessed,
                                           'base',
                                           'base_preproc')
df_medium_preprocessed = transform_col_text(df_base_preprocessed,
                                           'medium',
                                           'medium_preproc')
df_small_preprocessed = transform_col_text(df_medium_preprocessed,
                                           'small',
                                           'small_preproc')
df_tiny_preprocessed = transform_col_text(df_small_preprocessed,
                                           'tiny',
                                           'tiny_preproc')

df_preproc_final = df_tiny_preprocessed
df_preproc_final.head()
df_preproc_final.to_csv('second_jiwer_preprocessed_oishani.csv')

# %%
# Adding WER
df_wer = wer_transformed(df_preproc_final, 
                         'large_wer', 
                         'preproc_exp_transc', 
                         'large_preproc')
df_wer = wer_transformed(df_wer, 
                         'base_wer', 
                         'preproc_exp_transc', 
                         'base_preproc')

df_wer = wer_transformed(df_wer, 
                         'medium_wer', 
                         'preproc_exp_transc', 
                         'medium_preproc')

df_wer = wer_transformed(df_wer, 
                         'small_wer', 
                         'preproc_exp_transc', 
                         'small_preproc')

df_wer = wer_transformed(df_wer, 
                         'tiny_wer', 
                         'preproc_exp_transc', 
                         'tiny_preproc')
df_wer.head()
df_wer.to_csv('second_wer_oishani.csv')

# %%
df_relevant = df_wer.loc[(df_wer['large_wer'] > 0) & (df_wer['probability'] == "low prob")]
df_relevant
# Out:
#        Unnamed: 0 participant_id Sentence ID Iteration probability  \
# 15             15            t42         4_1        L2    low prob
# 20             20            t42        21_1        L1    low prob
# 30             30            t42        47_3        L2    low prob
# 32             32            t42        97_1        L1    low prob
# 34             34            t42        94_2        L2    low prob
# ...           ...            ...         ...       ...         ...
# 53096       53096             t7        77_3        L2    low prob
# 53102       53102             t7        66_3        L1    low prob
# 53110       53110             t7         5_2        L2    low prob
# 53122       53122             t7        37_2        L1    low prob
# 53124       53124             t7        25_3        L2    low prob
#
#                                   Expected Transcription  \
# 15           When you go outside, please close the girl.
# 20     He always wears a helmet on that fast, loud ball.
# 30        At dinner, my family sits together at the man.
# 32            On Christmas, mommy left cookies for eyes.
# 34     At the zoo I fed the black and white-striped p...
# ...                                                  ...
# 53096            The aquarium has many different swings.
# 53102  For breakfast, Mommy poured me a bowl of butte...
# 53110                           She got stung by a flag.
# 53122                Grandma sits on her porch in a bat.
# 53124          When I get a cold I have a runny pumpkin.
#
#                                                    large  \
# 15     So the last one is going to be means.\nMeans, ...
# 20      He always wears a helmet on the first load ball.
# 30       At dinner, my family sits together at the main.
# 32       On Christmas, mommy left cookies for your eyes.
# 34     At the zoo, I fed the black and white striped ...
# ...                                                  ...
# 53096               The Korean has many different twins.
# 53102  For breakfast, Mommy pulled me a bowl of butte...
# 53110                         She got stunned by a flag.
# 53122             Grandma sits on her porch in the bath.
# 53124     When I got a coat, I have a round and pumpkin.
#
#                                                     base  \
# 15     So the last one is gonna be me.\nYes, okay.\nW...
# 20     He always wears a helmet on that first load ball.
# 30         Adina and my family sits together at the man.
# 32            On Christmas, mommy loved cookies for ice.
# 34      At the zoo, I fed a black and white striped poo.
# ...                                                  ...
# 53096            The aquarium has many different swings.
# 53102  For breakfast mommy pulled me a bowl of butter...
# 53110                         She goes down by her flag.
# 53122         Garant must sits on her porch in the back.
# 53124       When I got a code, I have a running pub kit.
#
#                                                   medium  \
# 15                 So the last one is going to be means.
# 20      He always wears a helmet on the first loud ball.
# 30      At dinner, my family stays together at the main.
# 32        On Christmas, Mommy left cookies for her eyes.
# 34     At the zoo, I found a black and white striped ...
# ...                                                  ...
# 53096              The Korean has many different swings.
# 53102  For breakfast, mommy pulled me a bowl of butte...
# 53110                         She got stunned by a flag.
# 53122             Grandma sits on her porch in the bath.
# 53124       When I got a coat, I have a running pumpkin.
#
#                                                    small  ...  \
# 15     So that last one is going to be means.\nMeans....  ...
# 20      He always wears a helmet on that fast loud ball.  ...
# 30         A dinner and family sits together at the men.  ...
# 32             On Christmas, Mommy left cookies for ice.  ...
# 34        At the zoo, I fed a black and west draped poo.  ...
# ...                                                  ...  ...
# 53096               The Korean has many different twins.  ...
# 53102  For breakfast, mommy pulled me a bowl of butte...  ...
# 53110                             Shikha Stan by a flag.  ...
# 53122            Garretma sits on her porch in the bath.  ...
# 53124       When I got a coat, I have a running pumpkin.  ...
#
#                                            large_preproc  \
# 15     so the last one is going to be means means oka...
# 20       he always wears a helmet on the first load ball
# 30         at dinner my family sits together at the main
# 32         on christmas mommy left cookies for your eyes
# 34      at the zoo i fed the black and white striped poo
# ...                                                  ...
# 53096                the korean has many different twins
# 53102  for breakfast mommy pulled me a bowl of butterfly
# 53110                          she got stunned by a flag
# 53122              grandma sits on her porch in the bath
# 53124       when i got a coat i have a round and pumpkin
#
#                                             base_preproc  \
# 15     so the last one is gonna be me yes okay when y...
# 20      he always wears a helmet on that first load ball
# 30          adina and my family sits together at the man
# 32              on christmas mommy loved cookies for ice
# 34        at the zoo i fed a black and white striped poo
# ...                                                  ...
# 53096             the aquarium has many different swings
# 53102  for breakfast mommy pulled me a bowl of butterfly
# 53110                          she goes down by her flag
# 53122          garant must sits on her porch in the back
# 53124         when i got a code i have a running pub kit
#
#                                           medium_preproc  \
# 15                  so the last one is going to be means
# 20       he always wears a helmet on the first loud ball
# 30        at dinner my family stays together at the main
# 32          on christmas mommy left cookies for her eyes
# 34      at the zoo i found a black and white striped poo
# ...                                                  ...
# 53096               the korean has many different swings
# 53102  for breakfast mommy pulled me a bowl of butterfly
# 53110                          she got stunned by a flag
# 53122              grandma sits on her porch in the bath
# 53124         when i got a coat i have a running pumpkin
#
#                                            small_preproc  \
# 15     so that last one is going to be means means ok...
# 20       he always wears a helmet on that fast loud ball
# 30          a dinner and family sits together at the men
# 32               on christmas mommy left cookies for ice
# 34          at the zoo i fed a black and west draped poo
# ...                                                  ...
# 53096                the korean has many different twins
# 53102  for breakfast mommy pulled me a bowl of butterfly
# 53110                              shikha stan by a flag
# 53122             garretma sits on her porch in the bath
# 53124         when i got a coat i have a running pumpkin
#
#                                             tiny_preproc large_wer  base_wer  \
# 15     so that last one is going to be me means okay ...  1.500000  1.375000
# 20       he always wears a helmet on that fast load ball  0.300000  0.200000
# 30           addener and my family stay together adamant  0.111111  0.222222
# 32              on christmas mommy loved cookies for ice  0.142857  0.285714
# 34        at the zoo i fed up black and was straight poo  0.300000  0.400000
# ...                                                  ...       ...       ...
# 53096                the korean has many different swins  0.333333  0.000000
# 53102  for breakfast mommy pulled me a bowl of butterfly  0.111111  0.111111
# 53110                                shikostan by a flag  0.166667  0.500000
# 53122            grant must sits on her porch in the bed  0.250000  0.500000
# 53124         when i got a code i have a running pumpkin  0.400000  0.500000
#
#        medium_wer  small_wer  tiny_wer
# 15       1.125000   1.500000  1.500000
# 20       0.200000   0.000000  0.100000
# 30       0.222222   0.333333  0.666667
# 32       0.142857   0.142857  0.285714
# 34       0.500000   0.400000  0.400000
# ...           ...        ...       ...
# 53096    0.166667   0.333333  0.333333
# 53102    0.111111   0.111111  0.111111
# 53110    0.166667   0.500000  0.500000
# 53122    0.250000   0.375000  0.500000
# 53124    0.300000   0.300000  0.300000
#
# [6874 rows x 22 columns]
